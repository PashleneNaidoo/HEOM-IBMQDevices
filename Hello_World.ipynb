# %%
# !pip install qiskit
# !pip install qiskit[visualization]

# %%
import qiskit

# %%
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.25.1', 'qiskit': '0.44.1', 'qiskit-aer': None, 'qiskit-ignis': None, 'qiskit-ibmq-provider': None, 'qiskit-nature': None, 'qiskit-finance': None, 'qiskit-optimization': None, 'qiskit-machine-learning': None}

# %%
from qiskit import IBMQ

# %%
# !pip install qiskit-ibmq-provider

# %%
IBMQ.save_account('e8286cff0e21dc8265d17f01d30e9dc62debe3bb6557f339f326fda4b97d2894de135f54fe2dee4e4e2319f5e7e8155b88c856b01502b8a0b9435607e4e6432e')

# %%
IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
from qiskit import *

# %%
qr=QuantumRegister(1)
cr=ClassicalRegister(1)
circuit=QuantumCircuit(qr,cr)
# !matplotlib inline
# Out:
# /bin/bash: line 1: matplotlib: command not found

# %%
circuit.x(qr[0])
#circuit.barrier(qr[0])

for i in range(75):
  circuit.barrier(qr[0])
  circuit.i(0)
  #circuit.barrier(qr[0])

circuit.barrier(qr[0])
circuit.measure(qr,cr)
circuit.draw(output='mpl')

# %%
# !pip install qiskit-aer

# %%
simulator= Aer.get_backend('qasm_simulator')

# %%
result=execute(circuit,backend= simulator).result()

# %%
from qiskit.tools.visualization import plot_histogram

# %%
plot_histogram(result.get_counts(circuit))

# %%
provider = IBMQ.get_provider('ibm-q')

# %%
qcomp = provider.get_backend('ibm_perth')

# %%
job=execute(circuit,backend= qcomp)

# %%
from qiskit.tools.monitor import job_monitor

# %%
job_monitor(job)
# Out:
# Job Status: job is queued (None)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-7c77fd3e9d2c> in <cell line: 1>()
# ----> 1 job_monitor(job)
#
# /usr/local/lib/python3.10/dist-packages/qiskit/tools/monitor/job_monitor.py in job_monitor(job, interval, quiet, output, line_discipline)
#     103         _interval_set = True
#     104
# --> 105     _text_checker(
#     106         job, interval, _interval_set, quiet=quiet, output=output, line_discipline=line_discipline
#     107     )
#
# /usr/local/lib/python3.10/dist-packages/qiskit/tools/monitor/job_monitor.py in _text_checker(job, interval, _interval_set, quiet, output, line_discipline)
#      42         print("{}{}: {}".format(line_discipline, "Job Status", msg), end="", file=output)
#      43     while status.name not in ["DONE", "CANCELLED", "ERROR"]:
# ---> 44         time.sleep(interval)
#      45         status = job.status()
#      46         msg = status.value
#
# KeyboardInterrupt:

# %%
result= job.result()

# %%
plot_histogram(result.get_counts(circuit))
